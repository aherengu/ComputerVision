# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline #Display graphs in cells in Jupyter

# %%
from PIL import Image

# %%
pic = Image.open("DATA/00-puppy.jpg")

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x1CA642154A8>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_arr
# Out:
# array([[[223, 225, 224],
#         [223, 225, 224],
#         [223, 225, 224],
#         ...,
#         [224, 224, 224],
#         [224, 224, 224],
#         [223, 225, 224]],
#
#        [[223, 225, 224],
#         [223, 225, 224],
#         [223, 225, 224],
#         ...,
#         [224, 224, 224],
#         [224, 224, 224],
#         [223, 225, 224]],
#
#        [[223, 225, 224],
#         [223, 225, 224],
#         [223, 225, 224],
#         ...,
#         [224, 224, 224],
#         [224, 224, 224],
#         [223, 225, 224]],
#
#        ...,
#
#        [[ 80,  42,  33],
#         [ 80,  42,  33],
#         [ 81,  41,  33],
#         ...,
#         [ 77,  33,  24],
#         [ 77,  33,  24],
#         [ 74,  35,  20]],
#
#        [[ 77,  40,  31],
#         [ 74,  36,  27],
#         [ 70,  30,  22],
#         ...,
#         [ 78,  34,  25],
#         [ 77,  33,  24],
#         [ 74,  35,  20]],
#
#        [[ 84,  37,  29],
#         [ 75,  28,  20],
#         [ 72,  25,  17],
# ...

# %%
pic_red=pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (225, 225, 3)

# %%
pic_red=pic_red[:,:,0] #RGB

# %%
plt.imshow(pic_red)

# %%
plt.imshow(pic_red,cmap="gray")

# %%
plt.imshow(pic_arr[:,:,1],cmap="gray")

# %%
plt.imshow(pic_arr[:,:,2],cmap="gray")

# %%
pic_arrCopy=pic_arr.copy()
pic_no_red = pic_arrCopy.copy()
pic_no_red[:, :, 0] = 0  

pic_no_green = pic_arrCopy.copy()
pic_no_green[:, :, 1] = 0  

pic_no_blue = pic_arrCopy.copy()
pic_no_blue[:, :, 2] = 0

# %%
plt.imshow(pic_no_red)

# %%
plt.imshow(pic_no_green)

# %%
plt.imshow(pic_no_blue)
