# %%
#first shutdown all kernel except this

# %%
import cv2
cap=cv2.VideoCapture(0)

width=int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

writer=cv2.VideoWriter("mySuperDuperWonderVideHoy",cv2.VideoWriter_fourcc(*"DIVX"),20,(width,height)) #for windows
#macos or linux *"XVID"


while True:
    ret,frame=cap.read()

    writer.write(frame)
    
    #gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    #cv2.imshow("frame",gray)
    cv2.imshow("frame",frame)
    if cv2.waitKey(1) & 0xFF==ord("q"):
        break

cap.release()
writer.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-0b3806b569f6> in <module>
#       5 height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#       6
# ----> 7 writer=cv2.VideoWriter("mySuperDuperWonderVideHoy",cv2.Video)
#       8
#       9 while True:
#
# AttributeError: module 'cv2' has no attribute 'Video'

# %%
pwd
