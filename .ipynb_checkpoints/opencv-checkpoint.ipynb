# %%
import numpy as np
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread("DATA/00-puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(img)

# %%
#Matplot RGB
#OpenCV BGR

# %%
fix_image=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_image)

# %%
img_gray=cv2.imread("DATA/00-puppy.jpg",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap="gray")

# %%
plt.imshow(img_gray,cmap="magma")

# %%
plt.imshow(fix_image)

# %%
fix_image.shape
# Out:
# (225, 225, 3)

# %%
new_img=cv2.resize(fix_image,(1000,400)) #first is width second is height

# %%
plt.imshow(new_img)

# %%
w_ratio=0.1
h_ratio=0.1

# %%
new_img=cv2.resize(new_img,(0,0),fix_image,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
plt.imshow(cv2.flip(fix_image,0)) #0,1,-1

# %%
cv2.imwrite("totaly_new.jpg",new_img)
# Out:
# True

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
ax.imshow(new_img)
