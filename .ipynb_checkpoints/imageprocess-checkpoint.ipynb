# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread("DATA/00-puppy.jpg")

# %%
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
img_use=img.copy()

# %%
img_use=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img_use)

# %%
img_use=cv2.cvtColor(img,cv2.COLOR_RGB2HLS)
plt.imshow(img_use)
